# %%
# %matplotlib notebook 
from pandas import read_csv
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation, PillowWriter 
import numpy as np

# %% [markdown]
# ## Importing csv

# %%
df = read_csv("first_trajectory.csv")
x_0 = df['x0'].to_numpy().tolist()
y_0 = df['y0'].to_numpy().tolist()
x_1 = df['x1'].to_numpy().tolist()
y_1 = df['y1'].to_numpy().tolist()
x0, y0, x1, y1 = [], [], [], []


fig = plt.figure()
ax = plt.axes()
line, = ax.plot([], [], lw=2)

#plt.style.use("ggplot")
def init():  
    ax.set_xlim(-5, 5)  
    ax.set_ylim(-2, 2)  

def update(i): 
    x0.append((x_0[i]))
    y0.append((y_0[i]))
    #x1.append((x_1[i]))
    #y1.append((y_1[i]))
    line.set_data(x0, y0) 
    #ax.plot(x0, y0, color="red")
    #ax.plot(x1, y1, color="blue")

ani = FuncAnimation(fig, update, init_func=init, frames=200, interval=20)
plt.show()
# Out:
# <div id='c84018e4-7160-45bb-90ec-74cdd702548e'></div>

# %%
#ani.save('growingCoil.mp4', writer = 'pillow', fps = 30)
#plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
